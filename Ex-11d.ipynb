# %%
# Python program to build flashcard using class in Python
# Shuffle a deck of card with OOPS in Python
# How to create an empty class in Python?
# Student management system in Python

# %%
1

# %%
class Flashcard:
    def __init__(self, question, answer):
        self.question = question
        self.answer = answer

    def display_question(self):
        return self.question

    def display_answer(self):
        return self.answer


class FlashcardApp:
    def __init__(self):
        self.flashcards = []

    def add_flashcard(self, question, answer):
        new_flashcard = Flashcard(question, answer)
        self.flashcards.append(new_flashcard)

    def show_flashcards(self):
        for index, flashcard in enumerate(self.flashcards):
            print(f"Flashcard {index + 1}:")
            print(f"Question: {flashcard.display_question()}")
            print(f"Answer: {flashcard.display_answer()}")
            print()

    def quiz(self):
        for flashcard in self.flashcards:
            print(f"Question: {flashcard.display_question()}")
            input("Press Enter to show the answer...")
            print(f"Answer: {flashcard.display_answer()}")
            print()


def main():
    app = FlashcardApp()
    
    while True:
        print("1. Add Flashcard")
        print("2. Show Flashcards")
        print("3. Quiz Yourself")
        print("4. Exit")
        choice = input("Choose an option: ")

        if choice == '1':
            question = input("Enter the question: ")
            answer = input("Enter the answer: ")
            app.add_flashcard(question, answer)
        elif choice == '2':
            app.show_flashcards()
        elif choice == '3':
            app.quiz()
        elif choice == '4':
            print("Exiting the program.")
            break
        else:
            print("Invalid choice. Please choose a valid option.")

if __name__ == "__main__":
    main()
# Out:
# 1. Add Flashcard
# 2. Show Flashcards
# 3. Quiz Yourself
# 4. Exit
# Choose an option: 1
# Enter the question: how many people present?
# Enter the answer: 5
# 1. Add Flashcard
# 2. Show Flashcards
# 3. Quiz Yourself
# 4. Exit
# Choose an option: 2
# Flashcard 1:
# Question: how many people present?
# Answer: 5
#
# 1. Add Flashcard
# 2. Show Flashcards
# 3. Quiz Yourself
# 4. Exit
# Choose an option: 3
# Question: how many people present?
# Press Enter to show the answer...7
# Answer: 5
#
# 1. Add Flashcard
# 2. Show Flashcards
# 3. Quiz Yourself
# 4. Exit
# Choose an option: 1
# Enter the question: how many player in one team of cricket?
# Enter the answer: 11
# 1. Add Flashcard
# 2. Show Flashcards
# 3. Quiz Yourself
# 4. Exit
# Choose an option: 2
# Flashcard 1:
# Question: how many people present?
# Answer: 5
#
# Flashcard 2:
# Question: how many player in one team of cricket?
# Answer: 11
#
# 1. Add Flashcard
# 2. Show Flashcards
# 3. Quiz Yourself
# 4. Exit
# Choose an option: 2
# Flashcard 1:
# Question: how many people present?
# Answer: 5
#
# Flashcard 2:
# Question: how many player in one team of cricket?
# Answer: 11
#
# 1. Add Flashcard
# 2. Show Flashcards
# 3. Quiz Yourself
# 4. Exit
# Choose an option: 4
# Exiting the program.

# %%
#Shuffle a deck of card with OOPS in Python

# %%
import random

class Card:
    def __init__(self, suit, rank):
        self.suit = suit
        self.rank = rank

    def __str__(self):
        return f"{self.rank} of {self.suit}"


class Deck:
    def __init__(self):
        self.cards = []
        suits = ['Hearts', 'Diamonds', 'Clubs', 'Spades']
        ranks = ['2', '3', '4', '5', '6', '7', '8', '9', '10', 'Jack', 'Queen', 'King', 'Ace']
        self.cards = [Card(suit, rank) for suit in suits for rank in ranks]

    def shuffle(self):
        random.shuffle(self.cards)

    def deal_one(self):
        return self.cards.pop()

    def __str__(self):
        return '\n'.join(str(card) for card in self.cards)


def main():
    deck = Deck()
    print("Deck before shuffling:")
    print(deck)

    deck.shuffle()
    print("\nDeck after shuffling:")
    print(deck)

    print("\nDealing one card:")
    dealt_card = deck.deal_one()
    print(dealt_card)

if __name__ == "__main__":
    main()
# Out:
# Deck before shuffling:
# 2 of Hearts
# 3 of Hearts
# 4 of Hearts
# 5 of Hearts
# 6 of Hearts
# 7 of Hearts
# 8 of Hearts
# 9 of Hearts
# 10 of Hearts
# Jack of Hearts
# Queen of Hearts
# King of Hearts
# Ace of Hearts
# 2 of Diamonds
# 3 of Diamonds
# 4 of Diamonds
# 5 of Diamonds
# 6 of Diamonds
# 7 of Diamonds
# 8 of Diamonds
# 9 of Diamonds
# 10 of Diamonds
# Jack of Diamonds
# Queen of Diamonds
# King of Diamonds
# Ace of Diamonds
# 2 of Clubs
# 3 of Clubs
# 4 of Clubs
# 5 of Clubs
# 6 of Clubs
# 7 of Clubs
# 8 of Clubs
# 9 of Clubs
# 10 of Clubs
# Jack of Clubs
# Queen of Clubs
# King of Clubs
# Ace of Clubs
# 2 of Spades
# 3 of Spades
# 4 of Spades
# 5 of Spades
# 6 of Spades
# 7 of Spades
# 8 of Spades
# 9 of Spades
# 10 of Spades
# Jack of Spades
# Queen of Spades
# King of Spades
# Ace of Spades
#
# Deck after shuffling:
# Jack of Spades
# Queen of Hearts
# 3 of Clubs
# King of Hearts
# 5 of Clubs
# Queen of Diamonds
# 5 of Diamonds
# 10 of Spades
# 2 of Spades
# Jack of Clubs
# 4 of Clubs
# 8 of Hearts
# Ace of Spades
# 4 of Hearts
# 10 of Diamonds
# 7 of Hearts
# 2 of Clubs
# 4 of Spades
# 6 of Clubs
# Queen of Spades
# 3 of Diamonds
# 8 of Diamonds
# 4 of Diamonds
# Ace of Hearts
# 10 of Hearts
# 9 of Spades
# Ace of Clubs
# King of Diamonds
# Ace of Diamonds
# 5 of Hearts
# 6 of Spades
# 2 of Hearts
# 2 of Diamonds
# 8 of Spades
# 8 of Clubs
# 6 of Hearts
# Jack of Diamonds
# 3 of Hearts
# 3 of Spades
# 6 of Diamonds
# Queen of Clubs
# King of Clubs
# 9 of Diamonds
# 10 of Clubs
# 7 of Diamonds
# 7 of Spades
# 9 of Hearts
# 5 of Spades
# 9 of Clubs
# King of Spades
# Jack of Hearts
# 7 of Clubs
#
# Dealing one card:
# 7 of Clubs

# %%
#How to create an empty class in Python?

# %%
class MyEmptyClass:
    pass


obj = MyEmptyClass()


print(type(obj))
# Out:
# <class '__main__.MyEmptyClass'>

# %%
#Student management system in Python

# %%
class Student:
    def __init__(self, student_id, name, age, grade):
        self.student_id = student_id
        self.name = name
        self.age = age
        self.grade = grade

    def __str__(self):
        return f"ID: {self.student_id}, Name: {self.name}, Age: {self.age}, Grade: {self.grade}"


class StudentManagementSystem:
    def __init__(self):
        self.students = {}

    def add_student(self, student_id, name, age, grade):
        if student_id in self.students:
            print(f"Student with ID {student_id} already exists.")
        else:
            student = Student(student_id, name, age, grade)
            self.students[student_id] = student
            print(f"Student {name} added successfully.")

    def update_student(self, student_id, name=None, age=None, grade=None):
        if student_id in self.students:
            if name:
                self.students[student_id].name = name
            if age:
                self.students[student_id].age = age
            if grade:
                self.students[student_id].grade = grade
            print(f"Student {student_id} updated successfully.")
        else:
            print(f"Student with ID {student_id} does not exist.")

    def delete_student(self, student_id):
        if student_id in self.students:
            del self.students[student_id]
            print(f"Student {student_id} deleted successfully.")
        else:
            print(f"Student with ID {student_id} does not exist.")

    def display_student(self, student_id):
        if student_id in self.students:
            print(self.students[student_id])
        else:
            print(f"Student with ID {student_id} does not exist.")

    def display_all_students(self):
        if self.students:
            for student in self.students.values():
                print(student)
        else:
            print("No students in the system.")



def main():
    sms = StudentManagementSystem()

    while True:
        print("\n1. Add Student")
        print("2. Update Student")
        print("3. Delete Student")
        print("4. Display Student")
        print("5. Display All Students")
        print("6. Exit")
        choice = input("Choose an option: ")

        if choice == '1':
            student_id = input("Enter Student ID: ")
            name = input("Enter Student Name: ")
            age = int(input("Enter Student Age: "))
            grade = input("Enter Student Grade: ")
            sms.add_student(student_id, name, age, grade)
        elif choice == '2':
            student_id = input("Enter Student ID to update: ")
            name = input("Enter new name (leave blank to keep current): ")
            age = input("Enter new age (leave blank to keep current): ")
            grade = input("Enter new grade (leave blank to keep current): ")
            sms.update_student(student_id, name=name if name else None, age=int(age) if age else None, grade=grade if grade else None)
        elif choice == '3':
            student_id = input("Enter Student ID to delete: ")
            sms.delete_student(student_id)
        elif choice == '4':
            student_id = input("Enter Student ID to display: ")
            sms.display_student(student_id)
        elif choice == '5':
            sms.display_all_students()
        elif choice == '6':
            print("Exiting the program.")
            break
        else:
            print("Invalid choice. Please choose a valid option.")

if __name__ == "__main__":
    main()
# Out:
# 1. Add Student
# 2. Update Student
# 3. Delete Student
# 4. Display Student
# 5. Display All Students
# 6. Exit
# Choose an option: 4
# Enter Student ID to display: 11
# Student with ID 11 does not exist.
#
# 1. Add Student
# 2. Update Student
# 3. Delete Student
# 4. Display Student
# 5. Display All Students
# 6. Exit
# Choose an option: 1
# Enter Student ID: 11
# Enter Student Name: shyam
# Enter Student Age: 21
# Enter Student Grade: A
# Student shyam added successfully.
#
# 1. Add Student
# 2. Update Student
# 3. Delete Student
# 4. Display Student
# 5. Display All Students
# 6. Exit
# Choose an option: 1
# Enter Student ID: 12
# Enter Student Name: Ram
# Enter Student Age: 22
# Enter Student Grade: B
# Student Ram added successfully.
#
# 1. Add Student
# 2. Update Student
# 3. Delete Student
# 4. Display Student
# 5. Display All Students
# 6. Exit
# Choose an option: 5
# ID: 11, Name: shyam, Age: 21, Grade: A
# ID: 12, Name: Ram, Age: 22, Grade: B
#
# 1. Add Student
# 2. Update Student
# 3. Delete Student
# 4. Display Student
# 5. Display All Students
# 6. Exit
# Choose an option: 1
# Enter Student ID: 13
# Enter Student Name: Krishna
# Enter Student Age: 23
# Enter Student Grade: C
# Student Krishna added successfully.
#
# 1. Add Student
# 2. Update Student
# 3. Delete Student
# 4. Display Student
# 5. Display All Students
# 6. Exit
# Choose an option: 4
# Enter Student ID to display: 11
# ID: 11, Name: shyam, Age: 21, Grade: A
#
# 1. Add Student
# 2. Update Student
# 3. Delete Student
# 4. Display Student
# 5. Display All Students
# 6. Exit
# Choose an option: 5
# ID: 11, Name: shyam, Age: 21, Grade: A
# ID: 12, Name: Ram, Age: 22, Grade: B
# ID: 13, Name: Krishna, Age: 23, Grade: C
#
# 1. Add Student
# 2. Update Student
# 3. Delete Student
# 4. Display Student
# 5. Display All Students
# 6. Exit
# Choose an option: 3
# Enter Student ID to delete: 13
# Student 13 deleted successfully.
#
# 1. Add Student
# 2. Update Student
# 3. Delete Student
# 4. Display Student
# 5. Display All Students
# 6. Exit
# Choose an option: 5
# ID: 11, Name: shyam, Age: 21, Grade: A
# ID: 12, Name: Ram, Age: 22, Grade: B
#
# 1. Add Student
# 2. Update Student
# 3. Delete Student
# 4. Display Student
# 5. Display All Students
# 6. Exit
# Choose an option: 2
# Enter Student ID to update: 11
# Enter new name (leave blank to keep current): kana
# Enter new age (leave blank to keep current): 22
# Enter new grade (leave blank to keep current): D
# Student 11 updated successfully.
#
# 1. Add Student
# 2. Update Student
# 3. Delete Student
# 4. Display Student
# 5. Display All Students
# 6. Exit
# Choose an option: 5
# ID: 11, Name: kana, Age: 22, Grade: D
# ID: 12, Name: Ram, Age: 22, Grade: B
#
# 1. Add Student
# 2. Update Student
# 3. Delete Student
# 4. Display Student
# 5. Display All Students
# 6. Exit
# Choose an option: 6
# Exiting the program.
